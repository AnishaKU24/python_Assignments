# %% [markdown]
# ### List (Creation, Modification and Access):
# 1. List Creation:
#
# a. Create a list named age_list with five integer elements. For eg., [24, 25, 26, 27, 28]
#
# b. Create a list named name_list with five string elements.

# %%
age_list=[24,26,27,28,29]

# %%
age_list
# Out:
# [24, 26, 27, 28, 29]

# %%
name_list=['anisha','siniya','indrajith','sarath','anit']

# %%
name_list
# Out:
# ['anisha', 'siniya', 'indrajith', 'sarath', 'anit', 'Yazhini']

# %% [markdown]
# ### 2. List Operations / Modifications:
#
# a. Append the string "Yazhini" to name_list.
#
# b. Insert the element 30 at index 2 in age_list.
#
# c. Remove the string "Yazhini" from name_list.
#
# d. Pop the last element from age_list.
#
# e. Extend the age_list with additional ages [29, 30, 26].
#
# f. Sort age_list in descending order.
#
# g. Find Max age, Min age and sum of all ages from age_list.

# %%
name_list.append('Yazhini')

# %%
name_list
# Out:
# ['anisha', 'siniya', 'indrajith', 'sarath', 'anit', 'Yazhini']

# %%
age_list.insert(2,30)

# %%
age_list
# Out:
# [24, 26, 30, 27, 28, 29]

# %%
name_list.remove("Yazhini")

# %%
name_list
# Out:
# ['anisha', 'siniya', 'indrajith', 'sarath', 'anit']

# %%
age_list.pop()
# Out:
# 29

# %%
age_list.extend([29,30,26])

# %%
age_list
# Out:
# [24, 26, 30, 27, 28, 29, 30, 26]

# %%
age_list.sort(reverse=True)

# %%
age_list
# Out:
# [30, 30, 29, 28, 27, 26, 26, 24]

# %%
max_age=max(age_list)
min_age=min(age_list)
total_age=sum(age_list)
print (f"max_age:{max_age},min_age:{min_age},total_age:{total_age}")
# Out:
# max_age:30,min_age:24,total_age:220

# %% [markdown]
# ### 3. Accessing List Elements:
#
# a. Print the first element of name_list.
#
# b. Print the last element of name_list.
#
# c. Print the elements from index 2 to index 4 in name_list.
#
# d. Print the elements of name_list in reverse order.

# %%
name_list[0]
# Out:
# 'anisha'

# %%
name_list[-1]
# Out:
# 'anit'

# %%
name_list[2:5]
# Out:
# ['indrajith', 'sarath', 'anit']

# %%
name_list[::-1]
# Out:
# ['anit', 'sarath', 'indrajith', 'siniya', 'anisha']

# %% [markdown]
# ### Dictionary (Creation, Modification and Access):
#
# a. Create a dictionary named student_marks that maps the names of five
# students to their marks (use scale of from 0 to 100).
#
# b. Access and print the mark of a specific student, of your choice.
#
# c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
#
# d. Update the mark of any one older student to 82.
#
# e. Use the keys(), values(), and items() methods to print all keys, values, and
# key-value pairs in the student_marks dictionary.

# %%
student_marks={"Name":['anisha','siniya','sarath','zineerah','indrajith'],"Mark":[78,75,88,79,77]}

# %%
student_marks
# Out:
# {'Name': ['anisha', 'siniya', 'sarath', 'zineerah', 'indrajith'],
#  'Mark': [78, 75, 88, 79, 77]}

# %%
student_marks["Name"][4],student_marks["Mark"][4]
# Out:
# ('indrajith', 77)

# %%
student_marks["Name"].append("janani"),student_marks["Mark"].append(80)
student_marks
# Out:
# {'Name': ['anisha', 'siniya', 'sarath', 'zineerah', 'indrajith', 'janani'],
#  'Mark': [78, 75, 88, 79, 77, 80]}

# %%
student_marks["Mark"][3]=82
student_marks
# Out:
# {'Name': ['anisha', 'siniya', 'sarath', 'zineerah', 'indrajith', 'janani'],
#  'Mark': [78, 75, 88, 82, 77, 80]}

# %%
student_marks.keys()
# Out:
# dict_keys(['Name', 'Mark'])

# %%
student_marks.values()
# Out:
# dict_values([['anisha', 'siniya', 'sarath', 'zineerah', 'indrajith', 'janani'], [78, 75, 88, 82, 77, 80]])

# %%
student_marks.items()
# Out:
# dict_items([('Name', ['anisha', 'siniya', 'sarath', 'zineerah', 'indrajith', 'janani']), ('Mark', [78, 75, 88, 82, 77, 80])])

# %% [markdown]
# ### Sets (Operations):
# a. Create a set called my_set with following values:
# ['a','e','i','o','u','a','a','i']
# Analyse the output and provide explanation for the same.
#
# b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide
# an explanation.
#
# c. Create two sets:
# set1 with values: {1, 3, 5, 7, 9}
# set2 with values: {2, 3, 5, 8, 10}
#
# d. Compute and print the union and intersection of set1 and set2.

# %%
my_set={'a','e','i','o','u','a','a','i'}
my_set
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %% [markdown]
# set is not allowed duplicate values,it is unique and unodered.in my_set all duplicate values are removed,and displyed only unique values.

# %%
my_set[4] = 's'
#it shows typeError,because set is unorderd and unindexed.set doesn't store elements in fixed position.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 my_set[4] = 's'
#       2 #it shows typeError,because set is unorderd and unindexed.set doesn't store elements in fixed position.
#
# TypeError: 'set' object does not support item assignment

# %%
set1={1, 3, 5, 7, 9}

# %%
set1
# Out:
# {1, 3, 5, 7, 9}

# %%
set2={2, 3, 5, 8, 10}

# %%
set2
# Out:
# {2, 3, 5, 8, 10}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
set1.intersection(set2)
# Out:
# {3, 5}

# %% [markdown]
# ### Operators & Conditional Statements :
# (IF, ELIF, ELSE)
# Performance Category Program:
# 1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
# 2. Find the performance category based on the input score using following criteria:
# a. Above Average:  Score greater than 7
# b. Average: Score between 4 and 7(both inclusive)
# c. Below Average: Score lesser than 4
# 3. Output: Print the Performance category
# 4. Additional Step: You can give a prompt of your choice to each category.
# For eg: If score below average “Need to Improve your performance, consistent
# practice will lead to better results”.

# %%
score=int(input("Enter the score(0-10):"))
if 0<=score & score<=10:
    print("The score is:",score)
else:
    print("Invalid score! Plase enter a score between 0 and 10.")
# Out:
# Enter the score(0-10): 7
# The score is: 7

# %%
score=int(input("Enter the score(0-10):"))
if score>7:
 print("The Score is Above Average")
elif 4<=score<=7:
     print("The Score is Average")
else:
     print("The Score is Below Average")
# Out:
# Enter the score(0-10): 7
# The Score is Average

# %%
score=int(input("Enter the score(0-10):"))
if 0<=score & score<=10:
    if score>7 & score<=10:
        print(" Performance category:","Above Average")
    elif 4<=score<=7:
        print(" Performance category:","Average")
    else:
        print(" Performance category:","Below Average")
# Out:
# Enter the score(0-10): 7
#  Performance category: Average

# %%
score=int(input("Enter the score(0-10):"))
if score>7 & score<=10:
        print(" Performance category:","Above Average")
        print("Excellent performance! Keep up the great work")
elif 4<=score<=7:
        print(" Performance category:","Average")
        print("Good effort! Keep practicing and you can improve your performance further")
else:
        print(" Performance category:","Below Average")
        print("Your score is below average. Need to Improve your performance, consistent practice will lead to better results")
# Out:
# Enter the score(0-10): 8
#  Performance category: Above Average
# Excellent performance! Keep up the great work
